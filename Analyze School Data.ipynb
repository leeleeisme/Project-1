# %%
"""
This my attempt to analyze data, I downloaded the information from
your data set but as you can see I have some difficulties creating the code 
that I would like to show.
"""
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')
df.hist()
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='Year',y='School Name',color='DarkBlue',label='Schools');

# %%
df.count()
df.describe()
df.groupby(['School Level']).count()
df.groupby(['Number Scoring Below 65']).count()
df.head()
df.tail()
# Out:
#        School DBN           School Name School Level  \
# 212326     84X717  Icahn Charter School          K-8
# 212327     84X717  Icahn Charter School          K-8
# 212328     84X717  Icahn Charter School          K-8
# 212329     84X717  Icahn Charter School          K-8
# 212330     84X717  Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 212326           Living Environment  2016             8          s
# 212327           Living Environment  2016             5          s
# 212328           Living Environment  2017             6          s
# 212329           Living Environment  2017             4          s
# 212330  U.S. History and Government  2015             1          s
#
#        Number Scoring Below 65 Percent Scoring Below 65  \
# 212326                       s                        s
# 212327                       s                        s
# 212328                       s                        s
# ...

# %%
df.describe()
# Out:
#                 Year   Total Tested
# count  212331.000000  212331.000000
# mean     2015.956069      49.364200
# std         0.799726      93.023576
# min      2015.000000       1.000000
# 25%      2015.000000       5.000000
# 50%      2016.000000      20.000000
# 75%      2017.000000      57.000000
# max      2017.000000    1729.000000

# %%
df.groupby(['School Level']).count()
df.groupby(['Number Scoring Below 65']).count()
# Out:
#                          School DBN  School Name  School Level  Regents Exam  \
# Number Scoring Below 65
# 0                             10252        10252         10252         10252
# 1                              5978         5978          5978          5978
# 10                             3798         3798          3798          3798
# 100                              94           94            94            94
# 101                              99           99            99            99
# ...                             ...          ...           ...           ...
# 96                              110          110           110           110
# 97                              131          131           131           131
# 98                              106          106           106           106
# 99                              108          108           108           108
# s                             75222        75222         75222         75220
#
# ...
